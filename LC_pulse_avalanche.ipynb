# %%
__author__ = 'Anastasia Tsvetkova'
__email__  = 'tsvetkova.lea@gmail.com'

import yaml
# %matplotlib inline
from avalanche import LC, Restored_LC

# %% [markdown]
# ### Let's generate several light curves

# %%
lc = LC()
par = lc.generate_avalanche()
lc.plot_lc(save=False, show_duration=True)

# %%
lc = LC()
par = lc.generate_avalanche()
lc.plot_lc()

# %%
lc = LC(verbose=True)
par = lc.generate_avalanche()
lc.plot_lc()
# Out:
# Time resolution:  0.256
# Number of spontaneous pulses: 1
# --------------------------------------------------------------------------
# Spontaneous pulse amplitude: 0.978
# Spontaneous pulse shift: 6.031
# Time constant (the decay time) of spontaneous pulse: 5.065
# Rise time of spontaneous pulse: 2.532
# --------------------------------------------------------------------------
# Generating a new pulse with tau=5.065
# Number of pulses: 1
# --------------------------------------------------------------------------
# Generating a new pulse with tau=3.215
# Pulse amplitude: 0.995
# Pulse shift: 13.233
# Time constant (the decay time): 3.215
# Rise time: 1.607
# --------------------------------------------------------------------------
# Number of pulses: 1
# --------------------------------------------------------------------------
# Generating a new pulse with tau=3.192
# Pulse amplitude: 0.338
# Pulse shift: 60.550
# Time constant (the decay time): 3.192
# Rise time: 1.596
# --------------------------------------------------------------------------
# Number of pulses: 2
# --------------------------------------------------------------------------
# Generating a new pulse with tau=2.395
# Pulse amplitude: 0.294
# Pulse shift: 60.882
# Time constant (the decay time): 2.395
# Rise time: 1.197
# --------------------------------------------------------------------------
# Number of pulses: 4
# --------------------------------------------------------------------------
# Generating a new pulse with tau=1.890
# Pulse amplitude: 0.923
# Pulse shift: 72.420
# Time constant (the decay time): 1.890
# Rise time: 0.945
# --------------------------------------------------------------------------
# Number of pulses: 1
# --------------------------------------------------------------------------
# Generating a new pulse with tau=1.561
# Pulse amplitude: 0.644
# Pulse shift: 73.741
# Time constant (the decay time): 1.561
# Rise time: 0.780
# --------------------------------------------------------------------------
# Number of pulses: 2
# --------------------------------------------------------------------------
# Generating a new pulse with tau=1.416
# Pulse amplitude: 0.443
# Pulse shift: 76.176
# Time constant (the decay time): 1.416
# Rise time: 0.708
# --------------------------------------------------------------------------
# Number of pulses: 0
# --------------------------------------------------------------------------
# Generating a new pulse with tau=1.396
# Pulse amplitude: 0.919
# Pulse shift: 77.321
# Time constant (the decay time): 1.396
# Rise time: 0.698
# --------------------------------------------------------------------------
# Number of pulses: 0
# --------------------------------------------------------------------------
# Generating a new pulse with tau=1.993
# Pulse amplitude: 0.046
# Pulse shift: 60.947
# Time constant (the decay time): 1.993
# Rise time: 0.996
# --------------------------------------------------------------------------
# Number of pulses: 0
# --------------------------------------------------------------------------
# Generating a new pulse with tau=1.621
# Pulse amplitude: 0.949
# Pulse shift: 64.165
# Time constant (the decay time): 1.621
# Rise time: 0.811
# --------------------------------------------------------------------------
# Number of pulses: 1
# --------------------------------------------------------------------------
# Generating a new pulse with tau=1.138
# Pulse amplitude: 0.183
# Pulse shift: 68.123
# Time constant (the decay time): 1.138
# Rise time: 0.569
# --------------------------------------------------------------------------
# Number of pulses: 1
# --------------------------------------------------------------------------
# Generating a new pulse with tau=0.939
# Pulse amplitude: 0.944
# Pulse shift: 69.634
# Time constant (the decay time): 0.939
# Rise time: 0.470
# --------------------------------------------------------------------------
# Number of pulses: 1
# --------------------------------------------------------------------------
# Generating a new pulse with tau=0.587
# Pulse amplitude: 0.589
# Pulse shift: 71.493
# Time constant (the decay time): 0.587
# Rise time: 0.293
# --------------------------------------------------------------------------
# Number of pulses: 1
# --------------------------------------------------------------------------
# Generating a new pulse with tau=0.391
# Pulse amplitude: 0.721
# Pulse shift: 73.596
# Time constant (the decay time): 0.391
# Rise time: 0.196
# --------------------------------------------------------------------------
# Number of pulses: 1
# --------------------------------------------------------------------------
# Generating a new pulse with tau=0.342
# Pulse amplitude: 0.322
# Pulse shift: 73.990
# Time constant (the decay time): 0.342
# Rise time: 0.171
# --------------------------------------------------------------------------
# Number of pulses: 1
# --------------------------------------------------------------------------
# Generating a new pulse with tau=0.237
# Pulse amplitude: 0.333
# Pulse shift: 74.134
# Time constant (the decay time): 0.237
# Rise time: 0.119
# --------------------------------------------------------------------------
# Generating a new pulse with tau=2.285
# Pulse amplitude: 0.344
# Pulse shift: 63.947
# Time constant (the decay time): 2.285
# Rise time: 1.142
# --------------------------------------------------------------------------
# Number of pulses: 0
# --------------------------------------------------------------------------
# Generating a new pulse with tau=2.313
# Pulse amplitude: 0.464
# Pulse shift: 73.016
# Time constant (the decay time): 2.313
# Rise time: 1.157
# --------------------------------------------------------------------------
# Number of pulses: 0
# --------------------------------------------------------------------------

# %% [markdown]
# ### Let's open a yaml-file with avalanches and plot the T90 distribution for the sample

# %%
with open("./avalanche_parameters.yml", 'r') as f:
        loaded_data = yaml.safe_load(f)

# %%
for name in loaded_data:
    par_list = list(name.values())[0]
    lc = Restored_LC(par_list)
    lc.plot_lc()
